# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
data = pd.read_csv("incomecanada.csv")

# %%
X = data[["year"]].values
y = data[['income']].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X,y)

# %%
model = RandomForestRegressor()
model.fit(X_train,y_train)
# Out:
# <ipython-input-44-1cdd0c8af6ed>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X_train,y_train)
# RandomForestRegressor()

# %%
model.score(X_test,y_test)
# Out:
# 0.9813552462218106

# %%
plt.scatter(X,y)
plt.plot(X,model.predict(X),c='r')

# %%
model.predict([[2023]])
# Out:
# array([37729.8132667])

# %%
data[10:20]
# Out:
#     year        income
# 10  1980   8355.968120
# 11  1981   9434.390652
# 12  1982   9619.438377
# 13  1983  10416.536590
# 14  1984  10790.328720
# 15  1985  11018.955850
# 16  1986  11482.891530
# 17  1987  12974.806620
# 18  1988  15080.283450
# 19  1989  16426.725480
